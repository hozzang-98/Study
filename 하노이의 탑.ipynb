# %% [markdown]
# 하노이 탑(Tower of Hanoi)은 퍼즐의 일종입니다.
#
# 세 개의 기둥과 이 기동에 꽂을 수 있는 크기가 다양한 원판들이 있고, 퍼즐을 시작하기 전에는 한 기둥에 원판들이 작은 것이 위에 있도록 순서대로 쌓여 있습니다.
#
# 게임의 목적은 다음 두 가지 조건을 만족시키면서, 한 기둥에 꽂힌 원판들을 그 순서 그대로 다른 기둥으로 옮겨서 다시 쌓는 것입니다.

# %% [markdown]
# 1. 한 번에 하나의 원판만 옮길 수 있습니다.
# 2. 큰 원판이 작은 원판 위에 있어서는 안됩니다.

# %% [markdown]
# 하노이 탑의 세 개의 기둥을 왼쪽 부터 1번, 2번, 3번이라고 하겠습니다.
#
# 1번에는 n개의 원판이 있고 이 n개의 원판을 3번 원판으로 최소 횟수로 옮기려고 합니다.
#
#
# 1번 기둥에 있는 원판의 개수 n이 매개변수로 주어질 때, n개의 원판을 3번 원판으로 최소로 옮기는 방법을 return하는 solution를 완성해주세요.

# %% [markdown]
# n = 2
#
# return [ [1,2], [1,3], [2,3] ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 2

def solution(n):

    def hanoi(n, start, end, help): # 원판 개수, 시작 기둥, 목표 기둥, 보조 기둥

        if n == 1: # 원판이 하나면 바로 시작 기둥에서 목표 기둥으로 보내면 끝

            answer.append([start, end])

            return 

        hanoi(n-1, start, help, end) # 첫 이동 원판 빼고 나머지 원판들을, 보조 기둥에다가 몰아야 됨. 이 때 목표 기둥을 활용

        answer.append([start, end]) # 시작 기둥 -> 목표 기둥(보조로 활용한)

        hanoi(n-1, help, end, start) # 위의 과정에서 보조 기둥으로 몰아진 (n-1)개의 원판을 목표 기둥으로 옮긴다. 이 때 시작 기둥을 활용

    answer = []

    hanoi(n, 1, 3, 2)

    return answer

solution(n)
# Out:
# [[1, 2], [1, 3], [2, 3]]
